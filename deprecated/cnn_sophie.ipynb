# %%
#.............................................
# IMPORT STATEMENTS
#.............................................

# local env is py310

#General Python math functions
import math
#Loading in data (netcdf files)
import h5py
#Handling data
import numpy as np
import netCDF4 as nc
#Plotting figures
import matplotlib.pyplot as plt #Main plotting package
import cartopy.crs as ccrs
from cartopy.util import add_cyclic_point
import cartopy.mpl.ticker as cticker

#machine learning package
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.16.2

# %% [markdown]
# ### **getting data**

# %%
import os

# change to specific directory for user running code 
os.chdir("/Users/sophiekim/Desktop/2_research/MamalakisResearch") 
base_path = os.getcwd()

# everyone should have locally loaded 'data' folder
data_path = base_path + '/data/'

# %%
# initializing model list variable to call in function
model_list = [
    "CNRM_ESM2-1_ssp119_ssp126_201501_210012_r1-5_2pt5degree.nc",
    "MIROC6_ssp119_ssp126_201501_210012_r1-5_2pt5degree.nc",
    "MPI-ESM1-2-LR_ssp119_ssp126_201501_210012_r1-5_2pt5degree.nc",
    "MRI-ESM2-0_ssp119_ssp126_201501_210012_r1-5_2pt5degree.nc",
    "UKESM1-0-LL_ssp119_ssp126_201501_210012_r1-5_2pt5degree.nc",
]

# %% [markdown]
# #### **converting units**

# %%
def convert_units(varname: str, x: np.ndarray):
    """
    varname: index number from the list of variables so get_data func can convert units 
    x: data that needs units changed (raw x data) in get_data func 
    """
    if varname in {"tas", "tasmax", "tasmin"}:
        # kelvin to celcius
        return x - 273.15, "$^{\circ}$C"
    if varname == "pr":
        # kg/m2/s to mm/day
        return x * 86400.0, "mm/day"
    if varname == "psl":
        # pascals to hpa
        return x / 100.0, "hPa"
    
    # these don't need to be converted -- just adding the units 
    if varname == "sfcWind":
        return x, "m/s"
    if varname == "mrsos":
        return x, "kg/m$^{2}$"
    return x, "unknown"

# %% [markdown]
# #### **prepping tensors**

# %%
def get_model_name(path: str) -> str:
    """
    helper function so that get_cnn_tensors prints out the models that are being processed
    pulled from hayeon's code 
    """
    # Everything before "_ssp..."
    return os.path.basename(path).split("_ssp")[0]

# %%
def get_cnn_tensors(model_list, scenario, data_path, 
                    st_early=2015, end_early=2024, 
                    st_late=2050, end_late=2059,
                    stat='mean', use_anomaly=True, 
                    models_to_run=None, file_start_year=2015, 
                    vars_to_use=None):
    
    """
    model_list: variable of list of models
    scenario: input as either 'ssp119' or 'ssp126' strings
    data_path: variable of data_path for user
    st_early: early period start yr integer
    end_early: early period end yr integer
    st_late: late period start yr integer
    end_late: late period end yr integer
    stat: what stat function user wants to run to summarize variables 
        mean: mean
        std: standard deviation
        max: max val
        min: min val
        medium: median
    use_anomaly: whether to subtract values from baseline values to find anomaly
        True: subtract values
        False: don't subtract values 
    models_to_run: can specify number of models to run by index of model_list variable
        None: all models 
        [x]: one model to run 
        [x, x, x...]: whatever number of models to run 
    file_start_year: ensuring that if time dimension in models starts at 0 or 1, the func will slice the time correctly 
    vars_to_use: give list of strings of vars to calculate, if none specified (aka default) then does all 7 vars
    """
    # defining variable list for unit conversion later 
    var_list = ["tas", "tasmax", "tasmin", "pr", "psl", "sfcWind", "mrsos"]
    # default of calculating with all 7 vars
    if vars_to_use is None:
        selected_vars = var_list
    # if user specified certains vars to be calculated
    else:
        # check to see that the string items provided do exist
        selected_vars = [v for v in vars_to_use if v in var_list]

    # find the indexes of the specified variables defined by user (or defaulting to finding all the vars' indices)
    var_indices = [var_list.index(v) for v in selected_vars]

    # mapping out stats and the relevant func
    stat_map = {'mean': np.nanmean, 'std': np.nanstd, 'max': np.nanmax, 'min': np.nanmin, 'median': np.nanmedian}
    # variable that will calculate the stat for whatever the user wants and then will default to mean 
    calc_func = stat_map.get(stat.lower(), np.nanmean)

    # runs all models 
    if models_to_run is None:
        selected_models = model_list
    # runs one model if user only specified one
    elif isinstance(models_to_run, int):
        selected_models = [model_list[models_to_run]]
    # if none of the above options (all or one) was selected, then was list of models so get those models 
    else:
        selected_models = [model_list[i] for i in models_to_run]

    # initializing lists 
    x_list, y_list = [], []

    # opening file 
    for filename in selected_models:
        full_path = os.path.join(data_path, filename)
        model_short_name = get_model_name(filename)
        print(f"processing model: {model_short_name}")
        
        with nc.Dataset(full_path) as ds:
            # loading the data for specific model 
                # slicing dimensions for the ensembles, the specific var indices and all the times/long/lat dimensions
            data_all_vars = ds[f"data_{scenario}"][:, var_indices, :, :, :] 


            # starting unit conversions for ALL variables
            # looping through all 7 vars or the selected vars only 
                # using enumerate to keep track of the index of var and what the var is in the var_list defined above
                    # idx to keep track of what slice of the var dimension 
                    # var_name so that convert_units can be called correctly 
            for idx, var_name in enumerate(selected_vars):
                # converting var to relevant unit from func -- slicing the relevant var one at a time (getting all the info for all the other dimensions, just associated with that certain var)
                    # returns the converted numbers and string that gives converted unit
                converted_data, _ = convert_units(var_name, data_all_vars[:, idx, :, :, :])
                 # taking all the converted data and making it the 'all data' version for the var index 
         
            # slice early period once per climate model file
            m_early_start = (st_early - file_start_year) * 12
            m_early_end = (end_early - file_start_year) * 12 + 12
            baseline_slice = data_all_vars[:, :, m_early_start:m_early_end, :, :]
            
            
            # average ensembles (0 dimen) and months (2 dimen)
            p_mean = np.nanmean(baseline_slice, axis=(0, 2)) 
            p_std = np.nanstd(baseline_slice, axis=(0, 2))
            # if the standard deviation is less than super small, make it 1.0
            p_std[p_std < 1e-4] = 1.0

            # making list of periods where early period assigned 0 and late assigned 1 
            periods = [(st_early, end_early, 0), (st_late, end_late, 1)]

            # going thru periods 
            for start_yr, end_yr, label in periods:
                # making var for the number of ensembles are getting looked at 
                n_ens = data_all_vars.shape[0]
                
                # going thru every yr within each period 
                for yr_idx in range(start_yr, end_yr + 1):
                    # indexing by month 
                    m_idx_start = (yr_idx - file_start_year) * 12
                    m_idx_end = m_idx_start + 12
                    
                    # going thru individual ensemble for current yr 
                    for ens_idx in range(n_ens):
                        # slicing to get the info at the ensemble index, all vars, time index, all lats/longs
                        annual_slice = data_all_vars[ens_idx, :, m_idx_start:m_idx_end, :, :]
                        # applying user specified stat func to make the monthly vals into aggregated yearly vals
                        yearly_val = calc_func(annual_slice, axis=1) 
                        
                        if use_anomaly:
                            # calculate val from subtracting the value from the above calculated mean and then deivde by standard deviation
                            val = (yearly_val - p_mean) / p_std
                        else:
                            val = yearly_val
                        
                        x_list.append(val)
                        y_list.append(label)

    return np.nan_to_num(np.array(x_list), nan=0.0), np.array(y_list).reshape(-1, 1)

# %% [markdown]
# ### **running data prep**

# %%
x_data, y_data = get_cnn_tensors(model_list, scenario='ssp126', data_path=data_path)
# Out:
# processing model: CNRM_ESM2-1
# /var/folders/v1/c8q_17915_v735dr_k_2fb7w0000gn/T/ipykernel_49627/3003169814.py:93: RuntimeWarning: Mean of empty slice
#   p_mean = np.nanmean(baseline_slice, axis=(0, 2))
# /Users/sophiekim/miniforge3/envs/climate_env/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /var/folders/v1/c8q_17915_v735dr_k_2fb7w0000gn/T/ipykernel_49627/3003169814.py:117: RuntimeWarning: Mean of empty slice
#   yearly_val = calc_func(annual_slice, axis=1)
# processing model: MIROC6
# processing model: MPI-ESM1-2-LR
# processing model: MRI-ESM2-0
# processing model: UKESM1-0-LL

# %% [markdown]
# ### **TRAIN TEST SPLIT**

# %%
from sklearn.model_selection import train_test_split


# getting test split out (50 samples)
X_temp, X_test, y_temp, y_test = train_test_split(
    x_data, y_data, test_size=50, random_state=42
)


# getting val split out (50 samples) 
    # so the remaining is the train (400 samples)
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=50, random_state=42
)

print(f"train size: {len(X_train)}")      # 400
print(f"validation size: {len(X_val)}")    # 50
print(f"test size: {len(X_test)}")        # 50
# Out:
# train size: 400
# validation size: 50
# test size: 50

# %%
# making sure shapes are good
print(f"X_train shape: {X_train.shape}")
print(f"Y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}")
print(f"Y_val shape: {y_val.shape}")
# Out:
# X_train shape: (400, 7, 144, 73)
# Y_train shape: (400, 1)
# X_val shape: (50, 7, 144, 73)
# Y_val shape: (50, 1)

# %% [markdown]
# ### **CREATING CNN**

# %%
from tensorflow.keras import layers, models

def create_cnn(input_shape):
    # creating sequential model so that output of layer 1 becomes input for layer 2, etc. 
    model = models.Sequential([
        # LAYER 1: 
            # 3x3 kernels
            # same padding (puts zeroes on the outsides so that output shape same as input)
            # data_format channels_first means that the channel (aka the sample) is first, then the long/lat stuff
        layers.Conv2D(128, (3, 3), strides=1, padding='same', activation='relu', 
                      input_shape=input_shape, data_format='channels_first'),
            
        # LAYER 1.5
            # maxpooling --> looking at 2x2 blocks and taking max 
        layers.MaxPooling2D((2, 2), data_format='channels_first'),
        
        # LAYER 2: 
            # same thing as above 
        layers.Conv2D(128, (3, 3), strides=1, padding='same', activation='relu', 
                      data_format='channels_first'),
        layers.MaxPooling2D((2, 2), data_format='channels_first'),
        
        # LAYER 3: 
            # same thing as above
        layers.Conv2D(64, (3, 3), strides=1, padding='same', activation='relu', 
                      data_format='channels_first'),
        layers.MaxPooling2D((2, 2), data_format='channels_first'),

        # LAYER 4: 
        layers.Conv2D(32, (3, 3), strides=1, padding='same', activation='relu', 
                      data_format='channels_first'),
        layers.MaxPooling2D((2, 2), data_format='channels_first'),
        
        # LAYER 5: 
        layers.Conv2D(16, (3, 3), strides=1, padding='same', activation='relu', 
                      data_format='channels_first'),
        layers.MaxPooling2D((2, 2), data_format='channels_first'),

        # using dropout to ensure model does not overfit / rely on single feature to make predictions 
            # turns off 30% of neurons during each training step 
        layers.Dropout(0.3), 
        
        # taking the 2d map (aka the long/lat) to a long 1d vector of numbers
        layers.Flatten(), 
        
        # FULLY CONNECTED LAYERS 
            # taking patterns found in convolutions and weighing against each other to see if they look like future climate
        layers.Dense(50, activation='relu'), 
            # refines decision making 
        layers.Dense(10, activation='relu'),
        
        # OUTPUT LAYER
            # one neuron 
            # sigmoid bc output should be between 0-1 
                # closer to 0 --> early period 
                # closer to 1 --> late period 
        layers.Dense(1, activation='sigmoid') 
    ])
    
    return model

# %%
# getting one sample from the 400 batch in x train 
    # and then model will go through everything 400 times for each sample in the batch 
input_dims = X_train.shape[1:] 

# building model 
model = create_cnn(input_dims)

# getting architecture and param summary for every step 
model.summary()
# Out:
# /Users/sophiekim/miniforge3/envs/climate_env/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_22"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_97 (Conv2D)              │ (None, 128, 144, 73)   │         8,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_73 (MaxPooling2D) │ (None, 128, 72, 36)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_98 (Conv2D)              │ (None, 128, 72, 36)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_74 (MaxPooling2D) │ (None, 128, 36, 18)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_99 (Conv2D)              │ (None, 64, 36, 18)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_75 (MaxPooling2D) │ (None, 64, 18, 9)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_100 (Conv2D)             │ (None, 32, 18, 9)      │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_76 (MaxPooling2D) │ (None, 32, 9, 4)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_101 (Conv2D)             │ (None, 16, 9, 4)       │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_77 (MaxPooling2D) │ (None, 16, 4, 2)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_22 (Dropout)            │ (None, 16, 4, 2)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_16 (Flatten)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_60 (Dense)                │ (None, 50)             │         6,450 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_61 (Dense)                │ (None, 10)             │           510 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_62 (Dense)                │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 259,627 (1014.17 KB)
#  Trainable params: 259,627 (1014.17 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

def train_cnn(x_train, y_train, x_val, y_val):
    # building CNN architecutre using func above 
    model = create_cnn(x_train.shape[1:])
    
    # optimizing model with adam & leanring rate 
        # adam computes individual adaptive learning rates for every individual weight in CNN
        # using binary cross entropy since  predicting late/early periods 
        # outputting model accuracy 
    model.compile(optimizer=Adam(learning_rate=0.000001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # early stopping 
        # val_loss for tracking validation loss 
        # if val_loss doesn't get better after 5 epochs, will stop 
        # restore_best_weights ensures that model goes back to epoch that had the lowest val loss
    early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

    # TRAINING PROCESS
        # history variable stores accuracy/loss for every epoch 
        # batch size means that model will look at x amount of climate maps, update weights, then move to next x amount 
    history = model.fit(x_train, y_train, 
                        epochs=1000, 
                        batch_size=16,
                        validation_data=(x_val, y_val),
                        callbacks=[early_stopping], 
                        verbose=1)
    
    return model, history

# %%
model, history = train_cnn(X_train, y_train, X_val, y_val)
# Out:
# Epoch 1/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 87ms/step - accuracy: 0.4625 - loss: 0.7218 - val_accuracy: 0.4400 - val_loss: 0.7141
# Epoch 2/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.5125 - loss: 0.7054 - val_accuracy: 0.4400 - val_loss: 0.7134
# Epoch 3/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5050 - loss: 0.7019 - val_accuracy: 0.4400 - val_loss: 0.7130
# Epoch 4/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.5675 - loss: 0.6936 - val_accuracy: 0.4400 - val_loss: 0.7125
# Epoch 5/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5325 - loss: 0.6984 - val_accuracy: 0.4400 - val_loss: 0.7126
# Epoch 6/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.5375 - loss: 0.6984 - val_accuracy: 0.4400 - val_loss: 0.7124
# Epoch 7/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5200 - loss: 0.6915 - val_accuracy: 0.4400 - val_loss: 0.7121
# Epoch 8/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.5400 - loss: 0.6969 - val_accuracy: 0.4400 - val_loss: 0.7116
# Epoch 9/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.4875 - loss: 0.7117 - val_accuracy: 0.4400 - val_loss: 0.7112
# Epoch 10/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.5250 - loss: 0.7016 - val_accuracy: 0.4400 - val_loss: 0.7113
# Epoch 11/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.5425 - loss: 0.6921 - val_accuracy: 0.4400 - val_loss: 0.7110
# Epoch 12/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5050 - loss: 0.7162 - val_accuracy: 0.4400 - val_loss: 0.7107
# Epoch 13/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5350 - loss: 0.7011 - val_accuracy: 0.4400 - val_loss: 0.7110
# Epoch 14/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.4950 - loss: 0.7051 - val_accuracy: 0.4400 - val_loss: 0.7105
# Epoch 15/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.4875 - loss: 0.7012 - val_accuracy: 0.4400 - val_loss: 0.7105
# Epoch 16/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.4850 - loss: 0.7146 - val_accuracy: 0.4400 - val_loss: 0.7106
# Epoch 17/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.5050 - loss: 0.7085 - val_accuracy: 0.4400 - val_loss: 0.7102
# Epoch 18/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.5075 - loss: 0.7111 - val_accuracy: 0.4400 - val_loss: 0.7101
# Epoch 19/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.5025 - loss: 0.7077 - val_accuracy: 0.4400 - val_loss: 0.7099
# Epoch 20/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.5275 - loss: 0.6970 - val_accuracy: 0.4400 - val_loss: 0.7099
# Epoch 21/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5500 - loss: 0.7000 - val_accuracy: 0.4400 - val_loss: 0.7101
# Epoch 22/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.
1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.5350 - loss: 0.6874 - val_accuracy: 0.4000 - val_loss: 0.7058
# Epoch 89/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.5800 - loss: 0.6804 - val_accuracy: 0.4000 - val_loss: 0.7057
# Epoch 90/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.5250 - loss: 0.6946 - val_accuracy: 0.4000 - val_loss: 0.7055
# Epoch 91/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.5475 - loss: 0.6876 - val_accuracy: 0.4000 - val_loss: 0.7056
# Epoch 92/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.5625 - loss: 0.6901 - val_accuracy: 0.4000 - val_loss: 0.7054
# Epoch 93/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.5700 - loss: 0.6770 - val_accuracy: 0.4200 - val_loss: 0.7051
# Epoch 94/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.5425 - loss: 0.6850 - val_accuracy: 0.4200 - val_loss: 0.7048
# Epoch 95/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.5450 - loss: 0.6844 - val_accuracy: 0.4200 - val_loss: 0.7047
# Epoch 96/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5350 - loss: 0.6772 - val_accuracy: 0.4000 - val_loss: 0.7052
# Epoch 97/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.5675 - loss: 0.6827 - val_accuracy: 0.4000 - val_loss: 0.7051
# Epoch 98/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5200 - loss: 0.6875 - val_accuracy: 0.4000 - val_loss: 0.7052
# Epoch 99/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5525 - loss: 0.6787 - val_accuracy: 0.4000 - val_loss: 0.7053
# Epoch 100/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.6000 - loss: 0.6678 - val_accuracy: 0.4000 - val_loss: 0.7050
# Epoch 101/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5900 - loss: 0.6737 - val_accuracy: 0.4200 - val_loss: 0.7047
# Epoch 102/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.5800 - loss: 0.6855 - val_accuracy: 0.4200 - val_loss: 0.7048
# Epoch 103/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5625 - loss: 0.6836 - val_accuracy: 0.4000 - val_loss: 0.7049
# Epoch 104/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5475 - loss: 0.6799 - val_accuracy: 0.4000 - val_loss: 0.7049
# Epoch 105/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5350 - loss: 0.6823 - val_accuracy: 0.4000 - val_loss: 0.7049
# Epoch 106/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5025 - loss: 0.6947 - val_accuracy: 0.4000 - val_loss: 0.7051
# Epoch 107/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.5675 - loss: 0.6821 - val_accuracy: 0.4000 - val_loss: 0.7052
# Epoch 108/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.5375 - loss: 0.6859 - val_accuracy: 0.4000 - val_loss: 0.7050
# Epoch 109/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5450 - loss: 0.6817 - val_accuracy: 0.4000 - val_loss: 0.7052
# Epoch 110/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.5800 - loss: 0.6782 - val_accuracy: 0.4000 - val_loss: 0.7049

# %% [markdown]
# **DIFF ARCH**

# %%
# DIFF ARCH
from tensorflow.keras import layers, models, regularizers

def create_cnn(input_shape):
    # creating sequential model so that output of layer 1 becomes input for layer 2, etc. 
    model = models.Sequential([
        # LAYER 1: 
            # 3x3 kernels
            # same padding (puts zeroes on the outsides so that output shape same as input)
            # data_format channels_first means that the channel (aka the sample) is first, then the long/lat stuff
        layers.Conv2D(64, (3, 3), strides=1, padding='same', activation='relu', 
                      input_shape=input_shape, data_format='channels_first', 
                      # prevent overfitting by using L2 
                        # ensures that model keeps a global outlook rather than looking at a specific spot on map 
                      kernel_regularizer=regularizers.l2(0.001)),
        # using batch normalization to recenter everything so loss is a lil bit more smooth
            # ensures that every variable is looked at equally even tho math might look diff across the board
        layers.BatchNormalization(axis=1),
        # LAYER 1.5
            # maxpooling --> looking at 2x2 blocks and taking max 
        layers.MaxPooling2D((2, 2), data_format='channels_first'),
        
        # LAYER 2: 
            # putting more kenrels in so networks learns more complex patterns 
        layers.Conv2D(128, (3, 3), strides=1, padding='same', activation='relu', 
                      data_format='channels_first'),
        layers.BatchNormalization(axis=1),
        layers.MaxPooling2D((2, 2), data_format='channels_first'),
        
        # LAYER 3: 
            # same thing as above
        layers.Conv2D(128, (3, 3), strides=1, padding='same', activation='relu', 
                      data_format='channels_first'),
        layers.BatchNormalization(axis=1),
        layers.MaxPooling2D((2, 2), data_format='channels_first'),

        # LAYER 4: 
        layers.Conv2D(128, (3, 3), strides=1, padding='same', activation='relu', 
                      data_format='channels_first'),
        layers.BatchNormalization(axis=1),
        layers.MaxPooling2D((2, 2), data_format='channels_first'),
        
        # LAYER 5: 
        layers.Conv2D(64, (3, 3), strides=1, padding='same', activation='relu', 
                      data_format='channels_first'),

         layers.Conv2D(32, (3, 3), strides=1, padding='same', activation='relu', 
                      data_format='channels_first'),

        # using dropout to ensure model does not overfit / rely on single feature to make predictions 
            # turns off x% of neurons during each training step 
        layers.Dropout(0.4), 
        
        # taking the 2d map (aka the long/lat) to a long 1d vector of numbers
        layers.Flatten(), 
        
        # FULLY CONNECTED LAYERS 
            # taking patterns found in convolutions and weighing against each other to see if they look like future climate
        layers.Dense(64, activation='relu'), 
            # refines decision making 
        layers.Dense(32, activation='relu'),
        
        # OUTPUT LAYER
            # one neuron 
            # sigmoid bc output should be between 0-1 
                # closer to 0 --> early period 
                # closer to 1 --> late period 
        layers.Dense(1, activation='sigmoid') 
    ])
    
    return model



# getting one sample from the 400 batch in x train 
    # and then model will go through everything 400 times for each sample in the batch 
input_dims = X_train.shape[1:] 

# building model 
model = create_cnn(input_dims)

# getting architecture and param summary for every step 
model.summary()
# Out:
# Model: "sequential_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_88 (Conv2D)              │ (None, 64, 144, 73)    │         4,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_46          │ (None, 64, 144, 73)    │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_67 (MaxPooling2D) │ (None, 64, 72, 36)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_89 (Conv2D)              │ (None, 128, 72, 36)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_47          │ (None, 128, 72, 36)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_68 (MaxPooling2D) │ (None, 128, 36, 18)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_90 (Conv2D)              │ (None, 128, 36, 18)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_48          │ (None, 128, 36, 18)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_69 (MaxPooling2D) │ (None, 128, 18, 9)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_91 (Conv2D)              │ (None, 128, 18, 9)     │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_49          │ (None, 128, 18, 9)     │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_70 (MaxPooling2D) │ (None, 128, 9, 4)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_92 (Conv2D)              │ (None, 64, 9, 4)       │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_93 (Conv2D)              │ (None, 32, 9, 4)       │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_20 (Dropout)            │ (None, 32, 9, 4)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_15 (Flatten)            │ (None, 1152)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_55 (Dense)                │ (None, 64)             │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_56 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_57 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 543,073 (2.07 MB)
#  Trainable params: 542,177 (2.07 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

def train_cnn(x_train, y_train, x_val, y_val):
    # building CNN architecutre using func above 
    model = create_cnn(x_train.shape[1:])
    
    # optimizing model with adam & leanring rate 
        # adam computes individual adaptive learning rates for every individual weight in CNN
        # using binary cross entropy since  predicting late/early periods 
        # outputting model accuracy 
    model.compile(optimizer=Adam(learning_rate=0.000001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # early stopping 
        # val_loss for tracking validation loss 
        # if val_loss doesn't get better after 5 epochs, will stop 
        # restore_best_weights ensures that model goes back to epoch that had the lowest val loss
    early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

    # TRAINING PROCESS
        # history variable stores accuracy/loss for every epoch 
        # batch size means that model will look at x amount of climate maps, update weights, then move to next x amount 
    history = model.fit(x_train, y_train, 
                        epochs=1000, 
                        batch_size=16,
                        validation_data=(x_val, y_val),
                        callbacks=[early_stopping], 
                        verbose=1)
    
    return model, history

# %%
def create_cnn_optimized(input_shape):
    model = models.Sequential([
        # BLOCK 1: Keep spatial resolution but start extracting features
        layers.Conv2D(64, (3, 3), padding='same', activation='relu', 
                      input_shape=input_shape, data_format='channels_first'),
        layers.BatchNormalization(axis=1),
        layers.MaxPooling2D((2, 2), data_format='channels_first'),
        
        # BLOCK 2: Increase filters
        layers.Conv2D(128, (3, 3), padding='same', activation='relu', data_format='channels_first'),
        layers.BatchNormalization(axis=1),
        layers.MaxPooling2D((2, 2), data_format='channels_first'),
        
        # BLOCK 3: Use Spatial Dropout to force feature independence
        layers.SpatialDropout2D(0.3, data_format='channels_first'), # <--- KEY CHANGE
        
        # BLOCK 4: Final Conv before GAP
        layers.Conv2D(64, (3, 3), padding='same', activation='relu', data_format='channels_first'),
        
        # THE FIX: Replace Flatten with Global Average Pooling
        layers.GlobalAveragePooling2D(data_format='channels_first'), # <--- KEY CHANGE
        
        # DENSE HEAD: Now much smaller and harder to overfit
        layers.Dense(32, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(1, activation='sigmoid') 
    ])
    return model

input_dims = X_train.shape[1:] 

# building model 
model = create_cnn(input_dims)

# getting architecture and param summary for every step 
model.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_53 (Conv2D)              │ (None, 64, 144, 73)    │         4,096 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 64, 144, 73)    │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_45 (MaxPooling2D) │ (None, 64, 72, 36)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_54 (Conv2D)              │ (None, 128, 72, 36)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 128, 72, 36)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_46 (MaxPooling2D) │ (None, 128, 36, 18)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_55 (Conv2D)              │ (None, 128, 36, 18)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_22          │ (None, 128, 36, 18)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_47 (MaxPooling2D) │ (None, 128, 18, 9)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_56 (Conv2D)              │ (None, 64, 18, 9)      │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_23          │ (None, 64, 18, 9)      │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_57 (Conv2D)              │ (None, 32, 18, 9)      │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 32, 18, 9)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_11 (Flatten)            │ (None, 5184)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 64)             │       331,840 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_35 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 653,281 (2.49 MB)
#  Trainable params: 652,513 (2.49 MB)
#  Non-trainable params: 768 (3.00 KB)

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

def train_cnn(x_train, y_train, x_val, y_val):
    # building CNN architecutre using func above 
    model = create_cnn_optimized(x_train.shape[1:])
    
    # optimizing model with adam & leanring rate 
        # adam computes individual adaptive learning rates for every individual weight in CNN
        # using binary cross entropy since  predicting late/early periods 
        # outputting model accuracy 
    model.compile(optimizer=Adam(learning_rate=0.000001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # early stopping 
        # val_loss for tracking validation loss 
        # if val_loss doesn't get better after 5 epochs, will stop 
        # restore_best_weights ensures that model goes back to epoch that had the lowest val loss
    early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)

    # TRAINING PROCESS
        # history variable stores accuracy/loss for every epoch 
        # batch size means that model will look at x amount of climate maps, update weights, then move to next x amount 
    history = model.fit(x_train, y_train, 
                        epochs=1000, 
                        batch_size=16,
                        validation_data=(x_val, y_val),
                        callbacks=[early_stopping], 
                        verbose=1)
    
    return model, history

# %%
def create_cnn(input_shape):
    model = models.Sequential([
        # Start with a larger kernel to capture broad climate patterns
        layers.Conv2D(32, (5, 5), padding='same', activation='relu', input_shape=input_shape, data_format='channels_first'),
        layers.BatchNormalization(axis=1),
        layers.MaxPooling2D((2, 2), data_format='channels_first'),
        
        layers.Conv2D(64, (3, 3), padding='same', activation='relu', data_format='channels_first'),
        layers.BatchNormalization(axis=1),
        
        # This replaces Flatten and usually fixes the 0.51/0.01 issue
        layers.GlobalAveragePooling2D(data_format='channels_first'),
        
        layers.Dense(32, activation='relu', kernel_initializer='he_normal'),
        layers.Dense(1, activation='sigmoid')
    ])
    
    # Use a very low learning rate
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model

input_dims = X_train.shape[1:] 

# building model 
model = create_cnn(input_dims)

# getting architecture and param summary for every step 
model.summary()

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

def train_cnn(x_train, y_train, x_val, y_val):
    # building CNN architecutre using func above 
    model = create_cnn(x_train.shape[1:])
    
    # optimizing model with adam & leanring rate 
        # adam computes individual adaptive learning rates for every individual weight in CNN
        # using binary cross entropy since  predicting late/early periods 
        # outputting model accuracy 
    model.compile(optimizer=Adam(learning_rate=0.000000000001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # early stopping 
        # val_loss for tracking validation loss 
        # if val_loss doesn't get better after 5 epochs, will stop 
        # restore_best_weights ensures that model goes back to epoch that had the lowest val loss
    early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

    # TRAINING PROCESS
        # history variable stores accuracy/loss for every epoch 
        # batch size means that model will look at x amount of climate maps, update weights, then move to next x amount 
    history = model.fit(x_train, y_train, 
                        epochs=1000, 
                        batch_size=64,
                        validation_data=(x_val, y_val),
                        callbacks=[early_stopping], 
                        verbose=1)
    
    return model, history
# Out:
# Model: "sequential_36"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_135 (Conv2D)             │ (None, 32, 144, 73)    │         5,632 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_74          │ (None, 32, 144, 73)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_103               │ (None, 32, 72, 36)     │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_136 (Conv2D)             │ (None, 64, 72, 36)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_75          │ (None, 64, 72, 36)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_18     │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_88 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_89 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,625 (104.00 KB)
#  Trainable params: 26,433 (103.25 KB)
#  Non-trainable params: 192 (768.00 B)

# %%
from tensorflow.keras import layers, models, regularizers

def create_cnn_optimized(input_shape):
    model = models.Sequential([
        # --- BLOCK 1: High Resolution Feature Extraction ---
        # We start with 32 filters to keep the model lightweight.
        layers.Conv2D(32, (3, 3), padding='same', activation='relu', 
                      input_shape=input_shape, data_format='channels_first'),
        layers.BatchNormalization(axis=1),
        # One MaxPooling to reduce spatial dimensions slightly (e.g., 144x72 -> 72x36)
        layers.MaxPooling2D((2, 2), data_format='channels_first'),
        
        # --- BLOCK 2: Learning Variable Independence ---
        # SpatialDropout2D is the "secret sauce" here. It drops an entire variable 
        # channel (e.g., hides all 'Precipitation' data) during training.
        # This forces the model to learn the signal from ALL variables, not just one.
        layers.SpatialDropout2D(0.2, data_format='channels_first'),
        
        layers.Conv2D(64, (3, 3), padding='same', activation='relu', data_format='channels_first'),
        layers.BatchNormalization(axis=1),
        # Second (and final) MaxPooling (e.g., 72x36 -> 36x18)
        layers.MaxPooling2D((2, 2), data_format='channels_first'),
        
        # --- BLOCK 3: Deep Feature Synthesis ---
        layers.Conv2D(128, (3, 3), padding='same', activation='relu', data_format='channels_first'),
        layers.BatchNormalization(axis=1),
        
        # --- THE GLOBAL STEP: Replace Flatten with GAP ---
        # Instead of Flattening (which creates millions of parameters), GAP takes the 
        # average of each 2D feature map. This reduces overfitting drastically.
        layers.GlobalAveragePooling2D(data_format='channels_first'),
        
        # --- FINAL DECISION HEAD ---
        layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
        layers.Dropout(0.5), # Standard dropout for the dense layer
        layers.Dense(32, activation='relu'),
        layers.Dense(1, activation='sigmoid') # Binary output: 0 (Early) or 1 (Late)
    ])
    
    return model

input_dims = X_train.shape[1:] 

# building model 
model = create_cnn_optimized(input_dims)

# getting architecture and param summary for every step 
model.summary()

def train_cnn(x_train, y_train, x_val, y_val):
    # building CNN architecutre using func above 
    model = create_cnn_optimized(x_train.shape[1:])
    
    # optimizing model with adam & leanring rate 
        # adam computes individual adaptive learning rates for every individual weight in CNN
        # using binary cross entropy since  predicting late/early periods 
        # outputting model accuracy 
    model.compile(optimizer=Adam(learning_rate=0.000000000001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # early stopping 
        # val_loss for tracking validation loss 
        # if val_loss doesn't get better after 5 epochs, will stop 
        # restore_best_weights ensures that model goes back to epoch that had the lowest val loss
    early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

    # TRAINING PROCESS
        # history variable stores accuracy/loss for every epoch 
        # batch size means that model will look at x amount of climate maps, update weights, then move to next x amount 
    history = model.fit(x_train, y_train, 
                        epochs=1000, 
                        batch_size=64,
                        validation_data=(x_val, y_val),
                        callbacks=[early_stopping], 
                        verbose=1)
    
    return model, history
# Out:
# Model: "sequential_45"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_156 (Conv2D)             │ (None, 32, 144, 73)    │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_87          │ (None, 32, 144, 73)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_119               │ (None, 32, 72, 36)     │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ spatial_dropout2d_17            │ (None, 32, 72, 36)     │             0 │
# │ (SpatialDropout2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_157 (Conv2D)             │ (None, 64, 72, 36)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_88          │ (None, 64, 72, 36)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_120               │ (None, 64, 36, 18)     │             0 │
# │ (MaxPooling2D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_158 (Conv2D)             │ (None, 128, 36, 18)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_89          │ (None, 128, 36, 18)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_27     │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_109 (Dense)               │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_35 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_110 (Dense)               │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_111 (Dense)               │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 105,665 (412.75 KB)
#  Trainable params: 105,217 (411.00 KB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
# ### THIS IS GOOD RIGHT HERE

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

def create_cnn_minimalist(input_shape):
    model = models.Sequential([
        # LAYER 1: Large kernel (5x5) to see broad warming trends
        layers.Conv2D(16, (5, 5), padding='same', activation='relu', 
                      input_shape=input_shape, data_format='channels_first'),
        layers.MaxPooling2D((2, 2), data_format='channels_first'),
        
        # LAYER 2: Standard extraction
        layers.Conv2D(32, (3, 3), padding='same', activation='relu', data_format='channels_first'),
        layers.MaxPooling2D((2, 2), data_format='channels_first'),
        
        layers.Conv2D(32, (3, 3), padding='same', activation='relu', data_format='channels_first'),
        layers.MaxPooling2D((2, 2), data_format='channels_first'),
        
        # THE SUMMARY: Global Average Pooling (Keep this!)
        layers.GlobalAveragePooling2D(data_format='channels_first'),
        
        # DENSE: Very small, very simple
        layers.Dense(16, activation='relu'),
        layers.Dense(1, activation='sigmoid')
    ])
    return model



input_dims = X_train.shape[1:] 

# building model 
model = create_cnn_minimalist(input_dims)

# getting architecture and param summary for every step 
model.summary()

def train_cnn(x_train, y_train, x_val, y_val):
    # building CNN architecutre using func above 
    model = create_cnn_minimalist(x_train.shape[1:])
    
    # optimizing model with adam & leanring rate 
        # adam computes individual adaptive learning rates for every individual weight in CNN
        # using binary cross entropy since  predicting late/early periods 
        # outputting model accuracy 
    model.compile(optimizer=Adam(learning_rate=0.00001),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # early stopping 
        # val_loss for tracking validation loss 
        # if val_loss doesn't get better after 5 epochs, will stop 
        # restore_best_weights ensures that model goes back to epoch that had the lowest val loss
    early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

    # TRAINING PROCESS
        # history variable stores accuracy/loss for every epoch 
        # batch size means that model will look at x amount of climate maps, update weights, then move to next x amount 
    history = model.fit(x_train, y_train, 
                        epochs=1000, 
                        batch_size=64,
                        validation_data=(x_val, y_val),
                        callbacks=[early_stopping], 
                        verbose=1)
    
    return model, history

model, history = train_cnn(X_train, y_train, X_val, y_val)
# Out:
# /Users/sophiekim/miniforge3/envs/climate_env/lib/python3.10/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_18 (Conv2D)              │ (None, 16, 144, 73)    │         2,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 16, 72, 36)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_19 (Conv2D)              │ (None, 32, 72, 36)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 32, 36, 18)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_20 (Conv2D)              │ (None, 32, 36, 18)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_20 (MaxPooling2D) │ (None, 32, 18, 9)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_6      │ (None, 32)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,249 (67.38 KB)
#  Trainable params: 17,249 (67.38 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 520ms/step - accuracy: 0.5175 - loss: 0.6989 - val_accuracy: 0.4400 - val_loss: 0.7010
# Epoch 2/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 381ms/step - accuracy: 0.5175 - loss: 0.6984 - val_accuracy: 0.4400 - val_loss: 0.7004
# Epoch 3/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 361ms/step - accuracy: 0.5175 - loss: 0.6980 - val_accuracy: 0.4400 - val_loss: 0.6997
# Epoch 4/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 369ms/step - accuracy: 0.5175 - loss: 0.6976 - val_accuracy: 0.4400 - val_loss: 0.6991
# Epoch 5/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 381ms/step - accuracy: 0.5175 - loss: 0.6972 - val_accuracy: 0.4400 - val_loss: 0.6985
# Epoch 6/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 411ms/step - accuracy: 0.5175 - loss: 0.6968 - val_accuracy: 0.4400 - val_loss: 0.6979
# Epoch 7/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 369ms/step - accuracy: 0.5175 - loss: 0.6964 - val_accuracy: 0.4400 - val_loss: 0.6974
# Epoch 8/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 384ms/step - accuracy: 0.5175 - loss: 0.6961 - val_accuracy: 0.4400 - val_loss: 0.6968
# Epoch 9/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 368ms/step - accuracy: 0.5175 - loss: 0.6957 - val_accuracy: 0.4400 - val_loss: 0.6963
# Epoch 10/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 373ms/step - accuracy: 0.5175 - loss: 0.6954 - val_accuracy: 0.4400 - val_loss: 0.6958
# Epoch 11/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 369ms/step - accuracy: 0.5175 - loss: 0.6950 - val_accuracy: 0.4400 - val_loss: 0.6953
# Epoch 12/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 368ms/step - accuracy: 0.5175 - loss: 0.6947 - val_accuracy: 0.4400 - val_loss: 0.6948
# Epoch 13/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 365ms/step - accuracy: 0.5125 - loss: 0.6944 - val_accuracy: 0.4600 - val_loss: 0.6943
# Epoch 14/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 3s 367ms/step - accuracy: 0
1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 314ms/step - accuracy: 0.9575 - loss: 0.1402 - val_accuracy: 0.9200 - val_loss: 0.1812
# Epoch 937/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 252ms/step - accuracy: 0.9575 - loss: 0.1402 - val_accuracy: 0.9200 - val_loss: 0.1808
# Epoch 938/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 299ms/step - accuracy: 0.9575 - loss: 0.1401 - val_accuracy: 0.9200 - val_loss: 0.1810
# Epoch 939/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 256ms/step - accuracy: 0.9575 - loss: 0.1401 - val_accuracy: 0.9200 - val_loss: 0.1809
# Epoch 940/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 290ms/step - accuracy: 0.9575 - loss: 0.1402 - val_accuracy: 0.9200 - val_loss: 0.1802
# Epoch 941/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 206ms/step - accuracy: 0.9575 - loss: 0.1400 - val_accuracy: 0.9200 - val_loss: 0.1801
# Epoch 942/1000
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 251ms/step - accuracy: 0.9575 - loss: 0.1399 - val_accuracy: 0.9200 - val_loss: 0.1801

# %%
# Check the difference between Late and Early samples in your actual training data
# checking difference between late & early samples in actual training data 
late_mean = X_train[y_train.flatten() == 1].mean()
early_mean = X_train[y_train.flatten() == 0].mean()
print(f"Global Signal Magnitude: {late_mean - early_mean}")
# Out:
# Global Signal Magnitude: 0.016900195740976846

# %%
# looking at test accuracy 
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {test_acc:.4f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.9800 - loss: 0.0507
# Test Accuracy: 0.9800

# %%
# check if model is actually discerning or just predicting random stuff 
preds = model.predict(X_val)
print(f"Pred Mean: {np.mean(preds):.2f}, Pred Std: {np.std(preds):.2f}")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Pred Mean: 0.54, Pred Std: 0.45

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.title('Training and Validation Loss as a Function of Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Compare the average map of Early vs Late
early_avg = np.mean(X_train[y_train.flatten() == 0], axis=0)
late_avg = np.mean(X_train[y_train.flatten() == 1], axis=0)

plt.imshow(late_avg[0] - early_avg[0], cmap='RdBu_r')
plt.title("Difference: Late Mean minus Early Mean")
plt.colorbar()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_climate_predictions(images, labels, predictions, correct=True):
    """
    images: the X data (test)
    labels: the Y data (test)
    predictions: the predictions 
    if correct set to True, function will look for correct predictions
    if correct set to False, function will look for incorrect preditions 
    """
    if correct:
        # finding indices where predictions are the same as Y data 
        idx_list = np.where(predictions == labels.flatten())[0]
        title_prefix = "Correct Prediction"
    else:
        # finding indices where predictions are not same as Y data
        idx_list = np.where(predictions != labels.flatten())[0]
        title_prefix = "Incorrect Prediction"

    # safety in case there are no correct or incorrect samples so code doesn't fail
    if len(idx_list) == 0:
        print(f"No samples found for {'correct' if correct else 'incorrect'} predictions.")
        return

    plt.figure(figsize=(15, 5))
    # looping at least 3 times through the index list where predictions are correct
    for i in range(min(3, len(idx_list))):
        # plot(s) with 1 row, 3 cols, then selects slot for current loop iteration 
        plt.subplot(1, 3, i+1)
        # picks random index in index list
            # aka random sample
        idx = np.random.choice(idx_list)
        
        # taking slice from x data that is the sample at the certain random index and then the lats and longs (getting rid of variable dimension)
        plt.imshow(images[idx, 0, :, :], cmap="RdBu_r") 
        plt.title(f"{title_prefix}\nTrue: {int(labels[idx])}, Pred: {int(predictions[idx])}")
        plt.colorbar(orientation='horizontal', pad=0.15)
        plt.axis('off')
    plt.tight_layout()
    plt.show()

# predicting in model using x test data 
raw_preds = model.predict(X_test)
# making preds into binary 
    # if pred is greater than 0.5 then given a 1
predictions = (raw_preds > 0.5).astype(int).flatten()


# running func 
plot_climate_predictions(X_test, y_test, predictions, correct=False)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# /var/folders/v1/c8q_17915_v735dr_k_2fb7w0000gn/T/ipykernel_49627/3323786195.py:37: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   plt.title(f"{title_prefix}\nTrue: {int(labels[idx])}, Pred: {int(predictions[idx])}")
