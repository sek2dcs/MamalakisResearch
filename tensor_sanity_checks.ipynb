# %% [markdown]
# ## CNN Tensors Sanity Checks
#
# A notebook to check the validity of get_cnn_tensors_v2 notebook

# %%
# %run get_cnn_tesnors_v2.ipynb
# Out:
# c:\Users\student\Desktop\mamalakis_research\MamalakisResearch
# Student recognized as user.
# processing model: CNRM_ESM2-1
# C:\Users\student\AppData\Local\Temp\ipykernel_41556\2171347437.py:103: RuntimeWarning: Mean of empty slice
#   var_avg = np.nanmean(yearly_baseline_slices, axis=(0,1))  # (144, 73) -- one global map per variable and model
# C:\Users\student\AppData\Local\Temp\ipykernel_41556\2171347437.py:112: RuntimeWarning: Mean of empty slice
#   var_std = np.sqrt(np.nanmean(squared_diffs, axis=(0,1)))
# C:\Users\student\AppData\Local\Temp\ipykernel_41556\2171347437.py:147: RuntimeWarning: Mean of empty slice
#   yearly_val = calc_func(annual_slice, axis=1) # (7, 144, 73)
# processing model: MIROC6
# processing model: MPI-ESM1-2-LR

# %%
plt.plot(y_data)

# %% [markdown]
# ^ the plot output in this case makes sense, since function now loops through one model at a time, so should be 50 (bc one model, 5 trajectories, 10 yrs) of early (so 0) and then late (so 1)

# %%
x_data.shape

# %%
plot_all_variables(x_data, y_data)

# %%
x_data, y_data = get_cnn_tensors(model_list, 'ssp119', data_path, use_anomaly=False)

# %%
plt.plot(y_data)

# %%
plot_all_variables(x_data, y_data)
